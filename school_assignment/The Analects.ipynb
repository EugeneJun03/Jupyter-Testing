# %% [markdown]
# ### The Analects
#
# - this program is for testing your memory of the Analects

# %%
Analects = {"군자는 근본에 힘쓰니, 근본이 확립되면 도(道)가 생기는 법이다. ()와 ()은 ()을 행하는 근본일 것이다.":("효","공경","인"),
            "유자가 말했다. ()가 행해지는 것은 ()가 중요하니, 선왕의 도는 이것을 아름답게 여겼다. 그러므로 작은 일과 큰 일 모두 이것을 따랐다.":("예","화기"),
            "“()으로 하는 정치는 비유하면, 북극성이 제자리에 머물러 있으면 뭇 별들이 그곳으로 향해 도는 것과 같다.”":("덕"),
            "백성을 ()으로 인도하고 ()로 규제하면, 백성들이 부끄러워할 줄도 알고 자연히 선(善)에 이를 것이다.":("덕","예"),
            "“군자는 천하의 일 중에서 꼭 해야 한다는 것도 없으며, 절대 하지 않는다는 것도 없어서 오직 ()를 따를 뿐이다.”":("의"),
            "“()에 따라 행동하면 원망을 많이 산다.”":("이익"),
            "“()가 없음을 걱정하지 말고 지위에 설 수 있는 ()을 갖추었는지 걱정하며, 자신을 알아주는 이가 없음을 걱정하지 말고 남에게 인정받을 수 있는 ()을 갖추기를 구해야 한다.”":("지위", "자격", "실상"),
            "공자께서 말씀하셨다. “참(증자)아, 나의 ()는 하나의 이치가 꿰고 있다.” 증자가 “예” 하고 대답하였다. 공자께서 나가시자, 문인(門人)들이 물었다. “무슨 말씀입니까?” 증자가 대답하였다. “선생님의 도는 ()과 ()일 뿐이네.”":("도","충","서"),
            "군자는 ()에 밝고, 소인은 ()에 밝다.":("의리", "이익"),
            "()이 있는 사람은 외롭지 않으니, 반드시 이웃이 있다.":("덕"),
            "사람이 사는 이치는 ()이니, ()하지 않은데도 살아 있는 것은 요행이 죽음을 면한 것이다.":("정직", "정직"),
            "()에 뜻을 두며, ()을 굳게 지키며, ()을 떠나지 않으며, ()에서 노닐어야 한다.":("도", "덕", "인", "예"),
            "공자께서는 네 가지로써 가르치셨으니, (), (), (), ()였다.":("학문","실천", "진실","신의"),
            "()이 멀리 있다고 여기는가? 내가 ()을 하고자 하면 ()이 이르는 것이다.":("인"),
            "만일 주공과 같은 아름다운 재주를 갖고 있더라도, ()하고 또 ()하다면 그 나머지는 볼 것이 없다.":("교만", "인색"),
            "나는 ()을 좋아하듯이 () 좋아하는 자를 보지 못하였다.":("여색", "덕"),
            "()을 잘 섬기지 못한다면 어떻게 귀신을 섬기겠는가?” 계로가 말했다. “감히 죽음에 대해서 여쭙겠습니다.” 공자가 말했다. “()을 모른다면 어떻게 죽음에 대해서 알겠는가?":("사람", "삶"),
            "안연이 인(仁)에 대해 여쭙자, 공자가 말했다.“자기의 ()을 이겨 ()로 돌아가는 것이 인(仁)이니, 하루라도 사욕을 이겨 예로 돌아가면 천하 사람들이 모두 그 인을 허여(許與-인정하다.)하네. 인을 하는 것은 ()에게 달려 있는 것이지, ()에게 달려 있는 것이겠는가?”":("사욕", "예", "자신", "남"),
            "()가 아니면 보지 말며, 예가 아니면 듣지 말며, 예가 아니면 말하지 말며, 예가 아니면 움직이지 말아야 하네.":("예"),
            "()을 풍족하게 하고, ()를 풍족하게 하고, 백성들이 윗사람에게 ()를 지키는 것이네.":("백성", "군대", "신의"),
            "정치는 () 한다는 뜻이니, 당신이 ()으로써 통솔한다면 누가 감히 바르게 하지 않겠습니까?":("바르게", "바름"),
            "군자는 ()를 이루되 ()하지 않으며, 소인은 ()하되 ()를 이루지 못한다.":("조화",  "부화뇌동"),
            "()하고 ()고 ()하고 ()이 ()에 가깝다.”":("강","굳세", "질박", "어눌함", "인"),
            "()하면서 ()이 없기는 어렵고, ()하면서 ()하지 않기는 쉽다.":("가난", "원망","부유", "교만"),
            "“()으로써 ()을 갚는 것이 어떻습니까?” 공자가 말했다. “그렇다면 무엇으로써 ()에 보답하겠는가? ()으로써 원한을 갚고, 은덕으로써 은덕을 갚아야 하네.”":("은덕", "원한", "은덕", "정직함"),
            "()을 원망하지 않고 ()을 탓하지 않으며, 아래로 인간의 일을 배어 위로 ()를 통달하였으니, 나를 알아주는 것은 ()일 것이네.":("하늘", "사람", "천리"),
            "“군자는 ()으로써 ()을 닦는다네.” 자로가 여쭈었다. “이와 같을 뿐입니까?” “자신을 닦아서 ()을 편안하게 해주어야 하네.” “이와 같을 뿐입니까?” “자신을 닦아서 ()을 편안하게 해주어야 하니, 자신을 닦아서 백성을 편안하게 해주는 것은 요순(堯舜)도 오히려 (자신이) 부족하다고 여기셨네.”":("경", "자신", "남", "백성"),
            "더불어 말한 만한데 함께 말하지 않으면 ()을 잃는 것이요, 더불어 말할 만하지 않은데 함께 말하면 ()을 잃는 것이니, 지혜로운 자는 사람을 잃지 않으며 또한 말을 잃지 않는다":("사람", "말"),
            "뜻이 있는 선비와 덕을 이룬 인자(仁者)는 살기 위해 ()을 해침은 없고, ()을 희생하여 인을 이룸은 있다.":("인", "자신"),
            }
A_keys =list(Analects.keys())
print(A_keys)
m = Analects["“()에 따라 행동하면 원망을 많이 산다.”"]
print(m)
# Out:
# ['군자는 근본에 힘쓰니, 근본이 확립되면 도(道)가 생기는 법이다. ()와 ()은 ()을 행하는 근본일 것이다.', '유자가 말했다. ()가 행해지는 것은 ()가 중요하니, 선왕의 도는 이것을 아름답게 여겼다. 그러므로 작은 일과 큰 일 모두 이것을 따랐다.', '“()으로 하는 정치는 비유하면, 북극성이 제자리에 머물러 있으면 뭇 별들이 그곳으로 향해 도는 것과 같다.”', '백성을 ()으로 인도하고 ()로 규제하면, 백성들이 부끄러워할 줄도 알고 자연히 선(善)에 이를 것이다.', '“군자는 천하의 일 중에서 꼭 해야 한다는 것도 없으며, 절대 하지 않는다는 것도 없어서 오직 ()를 따를 뿐이다.”', '“()에 따라 행동하면 원망을 많이 산다.”', '“()가 없음을 걱정하지 말고 지위에 설 수 있는 ()을 갖추었는지 걱정하며, 자신을 알아주는 이가 없음을 걱정하지 말고 남에게 인정받을 수 있는 ()을 갖추기를 구해야 한다.”', '공자께서 말씀하셨다. “참(증자)아, 나의 ()는 하나의 이치가 꿰고 있다.” 증자가 “예” 하고 대답하였다. 공자께서 나가시자, 문인(門人)들이 물었다. “무슨 말씀입니까?” 증자가 대답하였다. “선생님의 도는 ()과 ()일 뿐이네.”', '군자는 ()에 밝고, 소인은 ()에 밝다.', '()이 있는 사람은 외롭지 않으니, 반드시 이웃이 있다.', '사람이 사는 이치는 ()이니, ()하지 않은데도 살아 있는 것은 요행이 죽음을 면한 것이다.', '()에 뜻을 두며, ()을 굳게 지키며, ()을 떠나지 않으며, ()에서 노닐어야 한다.', '공자께서는 네 가지로써 가르치셨으니, (), (), (), ()였다.', '()이 멀리 있다고 여기는가? 내가 ()을 하고자 하면 ()이 이르는 것이다.', '만일 주공과 같은 아름다운 재주를 갖고 있더라도, ()하고 또 ()하다면 그 나머지는 볼 것이 없다.', '나는 ()을 좋아하듯이 () 좋아하는 자를 보지 못하였다.', '()을 잘 섬기지 못한다면 어떻게 귀신을 섬기겠는가?” 
# ...

# %%
import random

while True:
    n = random.choices(A_keys)
    ans =input(n).split()
    if Analects[n[0]] == tuple(ans):
        print("Good")
    elif ans == ["q"]:
        break
    else:
        print("No the answer should be", Analects[n[0]])
# Out:
# Good
# Good
# No the answer should be 인
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# No the answer should be 예
# Good
# Good
# Good
# Good
# Good
# No the answer should be 이익
# Good
# Good
# Good
# No the answer should be 이익
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# No the answer should be ('은덕', '원한', '은덕', '정직함')
# Good
# No the answer should be ('가난', '원망', '부유', '교만')
# Good
# Good
# Good
# Good
# No the answer should be 인
# Good
# Good
# Good
# No the answer should be 예
# No the answer should be 이익
# Good
# Good
# Good
# No the answer should be 인
# No the answer should be 의
# Good
# Good
# No the answer should be ('조화', '부화뇌동')
# No the answer should be 이익
# Good
# Good
# No the answer should be 덕
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# Good
# No the answer should be ('의리', '이익')
# No the answer should be 덕
# Good
# No the answer should be ('사욕', '예', '자신', '남')
# Good
# Good
# ...
